# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/M-Sheheryar-khan/FlyRank-ML-Internship-Starter-Repo/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Scoring and ranking, with the option of using binary classification to identify pages that should be prioritized for review because the final output involves scoring every page, ranking pages from highest priority to lowest priority and recommend an action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# I will create a proxy target based on historical performance signals and business rules. This target will identify pages that are likely candidates for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The primary success metric for this project will be Precision@20, which measures how many of the top 20 pages recommended by the model are actually strong candidates for content review based on the chosen target or proxy label.A higher Precision@20 means the model is placing the most valuable refresh opportunities near the top of the ranked list, making it more useful for real-world decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
lane2_df = df[
    [
        "content_id",
        "content_type",
        "impressions_90d",
        "clicks_90d",
        "ctr",
        "avg_position",
        "engagement_rate",
        "content_age_days",
        "days_since_last_update",
        "trend_direction"
    ]
]
print("One row represents one content page.")
print("Rows:", len(lane2_df))
print("Columns:", len(lane2_df.columns))

lane2_df["needs_review"] = pd.NA

lane2_df.head()
# Out:
# One row represents one content page.
# Rows: 30000
# Columns: 10
# /tmp/ipykernel_3008/3519123906.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lane2_df["needs_review"] = pd.NA
#              content_id     content_type  impressions_90d  clicks_90d   ctr  \
# 0  content_304f48230142  keyword article             3803          29  0.76
# 1  content_a1fb4e703a9e  keyword article            15320           7  0.05
# 2  content_9aa793d4d895  keyword article            12581          11  0.09
# 3  content_331d6c4de07b  keyword article            11751          58  0.49
# 4  content_d99b7a2d90ca  keyword article            19140          24  0.13
#
#    avg_position  engagement_rate  content_age_days  days_since_last_update  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule can only evaluate a small number of conditions at a time, such as content age or CTR. However, deciding whether a page should be reviewed depends on the interaction of multiple factors, including impressions, clicks, CTR,  engagement and content age. Machine learning can learn patterns across these combined signals and produce a more balanced prioritization than a single rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
